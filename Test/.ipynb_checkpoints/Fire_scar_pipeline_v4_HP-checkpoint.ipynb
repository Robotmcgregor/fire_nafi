# %% [markdown]
# # Fire_scar_pipeline_v1

# %% [markdown]
# working on Rob's HP Anaconda env python36

# %%
import osgeo.gdal as gdal
import os
from osgeo import ogr

# this sets the environmental variables for the prj folders 
# https://stackoverflow.com/questions/56764046/gdal-ogr2ogr-cannot-find-proj-db-error

#Gamming computer

os.environ['PROJ_LIB'] =  'C:\ProgramData\Anaconda3\envs\geo_env\Library\share\proj'
os.environ['GDAL_DATA'] = 'C:\ProgramData\Anaconda3\envs\geo_env\Library\share'

#HP laptop

#os.environ['PROJ_LIB'] = 'C:/Users/rmcgr/Anaconda3/Library/share/proj'
#os.environ['GDAL_DATA'] = 'C:/Users/rmcgr/Anaconda3/Library/share'

# %%
import pandas as pd
import geopandas as gpd
import os
import shutil
import glob

import numpy as np
import rasterio as rio
import rasterio.plot
import pyproj

import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns
import fiona
import rasterstats
from rasterstats import zonal_stats
# Out:
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
import fiona; fiona.supported_drivers
# Out:
# {'AeronavFAA': 'r',
#  'ARCGEN': 'r',
#  'BNA': 'raw',
#  'DXF': 'raw',
#  'CSV': 'raw',
#  'OpenFileGDB': 'r',
#  'ESRI Shapefile': 'raw',
#  'GeoJSON': 'rw',
#  'GPKG': 'rw',
#  'GML': 'raw',
#  'GPX': 'raw',
#  'GPSTrackMaker': 'raw',
#  'Idrisi': 'r',
#  'MapInfo File': 'raw',
#  'DGN': 'raw',
#  'PCIDSK': 'r',
#  'S57': 'r',
#  'SEGY': 'r',
#  'SUA': 'r'}

# %%
# Import in the cadastre and ensure the crs is set to GDA94
"""cadastre = gpd.read_file(r'U:\LIB_Common\Cadastre\Datasets\Av_data\Cadastre.shp')
cadastre.head()
cadastre.crs"""


#read in an excel sheet with all of the property names
"""properties = pd.read_excel(r"\\pgb-bas01\DENR_Satellite_Imagery$\Scratch\Zonal_Stats_Pipeline\Copy of landsatZonalStatsTiles2.xlsx")
properties["Property"] = properties["Property"].str.upper()
prop_list = properties.Property.unique().tolist()

shapefile_list =[]"""

# create individual property shapefiles from a list
"""for i in prop_list:
    #To select rows whose column value equals a scalar, some_value, use ==:
    prop = cadastre[cadastre["PROP_NAME"]== i]
    prop.reset_index(drop=True, inplace=True)
    prop['uid']= prop.index + 1
    print (i)
    file_path = (r"\\pgb-bas01\DENR_Satellite_Imagery$\Scratch\Zonal_Stats_Pipeline\shapefiles\property\new\propertytest_" + str.lower(i) + "_GDA94.shp")
    shapefile_list.append(file_path)
    print(prop.crs)
    #prop.crs = {'init': 'EPSG:4283'}
    #prop_gda94 = prop
    print(prop.crs)
    fig, ax = plt.subplots(figsize = (10,10))
    prop.plot(ax=ax)
    plt.show()
    prop.to_file(file_path, driver = 'ESRI Shapefile')"""
# Out:
# 'for i in prop_list:\n    #To select rows whose column value equals a scalar, some_value, use ==:\n    prop = cadastre[cadastre["PROP_NAME"]== i]\n    prop.reset_index(drop=True, inplace=True)\n    prop[\'uid\']= prop.index + 1\n    print (i)\n    file_path = (r"\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\new\\propertytest_" + str.lower(i) + "_GDA94.shp")\n    shapefile_list.append(file_path)\n    print(prop.crs)\n    #prop.crs = {\'init\': \'EPSG:4283\'}\n    #prop_gda94 = prop\n    print(prop.crs)\n    fig, ax = plt.subplots(figsize = (10,10))\n    prop.plot(ax=ax)\n    plt.show()\n    prop.to_file(file_path, driver = \'ESRI Shapefile\')'

# %%
# Import in the cadastre and ensure the crs is set to GDA94
cadastre = gpd.read_file(r"D:\Rob\fire\cadastre.shp")
cadastre.head()
cadastre.crs


#read in an excel sheet with all of the property names
properties = pd.read_excel(r"D:\Rob\fire\landsatZonalStatsTiles.xlsx")
properties["Property"] = properties["Property"].str.upper()
prop_list = properties.Property.unique().tolist()
print("Property list: ", prop_list)

shapefile_list =[]

# create individual property shapefiles from a list
for i in prop_list:
    #To select rows whose column value equals a scalar, some_value, use ==:
    prop = cadastre[cadastre["PROP_NAME"]== i]
    prop.reset_index(drop=True, inplace=True)
    prop['uid']= prop.index + 1
    print ("Prop as string: ", i)
    property1  = str.lower(i)
    property_name = property1.replace("_", " ")
    print(property_name)
    file_path = (r"D:\Rob\fire\test_properties\work_comp" + "\\" + property_name + "_GDA94.shp")
    shapefile_list.append(file_path)
    print(prop.crs)
    prop.crs = {'init': 'EPSG:4283'}
    prop_gda94 = prop
    print(prop_gda94.crs)
    fig, ax = plt.subplots(figsize = (10,10))
    prop_gda94.plot(ax=ax)
    plt.show()
    prop_gda94.to_file(file_path, driver = 'ESRI Shapefile')
# Out:
# Property list:  ['ALLAMBI', 'BIRRIMBA', 'CAMFIELD', 'CATTLE CREEK', 'ELIZABETH DOWNS', 'EPENARRA', 'HAYFIELD', 'INVERWAY', 'JINDARE', 'KATHERINE DOWNS', 'KILLARNEY', 'MARY RIVER WEST', 'MIDDLE CREEK', 'MONTEJINNI EAST', 'MONTEJINNI WEST', 'MURRAY DOWNS', 'RIVEREN', 'SHENANDOAH', 'SHENANDOAH EAST', 'TODD RIVER', 'WAVE HILL', 'WILLEROO', 'WONGALARA', 'TENNANT CREEK', 'BULLO RIVER', 'YAMBAH']
# Prop as string:  ALLAMBI
# allambi
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  BIRRIMBA
# birrimba
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  CAMFIELD
# camfield
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# Prop as string:  CATTLE CREEK
# cattle creek
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  ELIZABETH DOWNS
# elizabeth downs
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  EPENARRA
# epenarra
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  HAYFIELD
# hayfield
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  INVERWAY
# inverway
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  JINDARE
# jindare
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  KATHERINE DOWNS
# katherine downs
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# Prop as string:  KILLARNEY
# killarney
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  MARY RIVER WEST
# mary river west
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# Prop as string:  MIDDLE CREEK
# middle creek
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  MONTEJINNI EAST
# montejinni east
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# Prop as string:  MONTEJINNI WEST
# montejinni west
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  MURRAY DOWNS
# murray downs
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  RIVEREN
# riveren
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  SHENANDOAH
# shenandoah
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  SHENANDOAH EAST
# shenandoah east
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  TODD RIVER
# todd river
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  WAVE HILL
# wave hill
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  WILLEROO
# willeroo
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  WONGALARA
# wongalara
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  TENNANT CREEK
# tennant creek
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Prop as string:  BULLO RIVER
# bullo river
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# Prop as string:  YAMBAH
# yambah
# {'init': 'epsg:4283'}
# {'init': 'EPSG:4283'}
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
shapefile_list
# Out:
# ['D:\\Rob\\fire\\test_properties\\allambi_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\birrimba_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\camfield_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\cattle creek_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\elizabeth downs_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\epenarra_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\hayfield_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\inverway_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\jindare_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\katherine downs_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\killarney_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\mary river west_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\middle creek_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\montejinni east_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\montejinni west_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\murray downs_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\riveren_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\shenandoah_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\shenandoah east_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\todd river_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\wave hill_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\willeroo_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\wongalara_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\tennant creek_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\bullo river_GDA94.shp',
#  'D:\\Rob\\fire\\test_properties\\yambah_GDA94.shp']

# %%
# Import in the cadastre and ensure the crs is set to GDA94
cadastre = gpd.read_file(r"../../cadastre.shp")
#cadastre.head()
cadastre.crs

# %%
df = gpd.read_file(r'D:\\Rob\\fire\\test_properties\\bullo river_GDA94.shp')
#df = gpd.read_file(r"\\pgb-bas01\DENR_Satellite_Imagery$\Scratch\Zonal_Stats_Pipeline\shapefiles\property\new\property_" + str.lower(i) + "_GDA94.shp")

# %%
type(df)

# %%
df.total_bounds

# %%
df.crs

# %%
df.crs = {'init': 'epsg:4283'}

# %%
df.crs

# %%
def listdir(dirname,endfilename,scratchDir):
    """
    this function will return a list of files in a directory for the given file extention "endfilename". 
    """
    list_img = []
    
    #os.mkdir(scratchDir)
     
    for root, dirs, files in os.walk(dirname):
        for file in files:
            if file.endswith(endfilename):
                img = (os.path.join(root, file))
                list_img.append(img)
                #print (img)
                #shutil.copy(os.path.abspath(img), scratchDir)
    print("Script has finished")
    print(list_img)
    return list_img

dirname = r'D:\Rob\fire\NAFI_fire_rasters'
endfilename = 'MTHS.tif'
scratchDir = r'D:\Rob\fire\NAFI_fire_rasters'

listdir(dirname,endfilename,scratchDir)

#print(list_img)

# %%
 = ['D:\\Rob\\fire\\NAFI_fire_rasters\\FS2000_MTHS.tif',
 'D:\\Rob\\fire\\NAFI_fire_rasters\\FS2001_MTHS.tif',
 'D:\\Rob\\fire\\NAFI_fire_rasters\\FS2002_MTHS.tif',
 'D:\\Rob\\fire\\NAFI_fire_rasters\\FS2003_MTHS.tif',
 'D:\\Rob\\fire\\NAFI_fire_rasters\\FS2004_MTHS.tif',
 'D:\\Rob\\fire\\NAFI_fire_rasters\\FS2005_MTHS.tif',
 'D:\\Rob\\fire\\NAFI_fire_rasters\\FS2017_MTHS.tif',
 'D:\\Rob\\fire\\NAFI_fire_rasters\\FS2019MTHS.tif']

# %%
dirname = (r'Z:\Scratch\Zonal_Stats_Pipeline\shapefiles\property\gda94')
endfilename = '.shp'
scratchDir = (r'Z:\Scratch\Zonal_Stats_Pipeline\shapefiles\property\new')
"""
this function will return a list of files in a directory for the given file extention "endfilename". 
"""

list_img = []

for root, dirs, files in os.walk(dirname):
    for file in files:
        print(file)
        if file.endswith(endfilename):
            img = (os.path.join(root, file))
            list_img.append(img)
            #print (img)
            #shutil.copy(os.path.abspath(img), scratchDir)
#print("Script has finished")
list_img
shapefile_list = list_img


#dirname = r'U:\Working\Rangelands\Spatial Data\NAFI Firescars'
#endfilename = 'MTH.tif'
#scratchDir = r'C:\Users\rmcgr\Desktop\firemaps\scratch'

# %%
shapefile_list

# %%
shapefile_list = ['Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_birrimba_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_bullo river_GDA94.shp',

 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_epenarra_GDA94.shp',

 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_inverway_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_jindare_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_katherine downs_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_killarney_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_mary river west_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_middle creek_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_montejinni east_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_montejinni west_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_murray downs_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_riveren_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_shenandoah east_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_shenandoah_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_tennant creek_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_todd river_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_wave hill_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_willeroo_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_wongalara_GDA94.shp',
 'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_yambah_GDA94.shp']

# %%
faulty_property_list = ['Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_camfield_GDA94.shp',
                        'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_cattle creek_GDA94.shp',
                        'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_elizabeth downs_GDA94.shp',
                       'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_elizabeth downs_GDA94.shp',
                        'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_hayfield_GDA94.shp',
                       'Z:\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_inverway_GDA94.shp',]

# %%
shapefile_list = ['\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_middle creek_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_montejinni east_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_montejinni west_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_shenandoah_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_shenandoah east_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_todd river_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_wave hill_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_willeroo_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_wongalara_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_tennant creek_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_bullo river_GDA94.shp',
 '\\\\pgb-bas01\\DENR_Satellite_Imagery$\\Scratch\\Zonal_Stats_Pipeline\\shapefiles\\property\\new\\property_yambah_GDA94.shp']

# %%
# %run D:\Rob\OS\list_of_files_multi_dir.py --direc Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2 --endfilen .tif --txtfile Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\list_of_files.csv
# Out:
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2000_MTHS.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2001_MTHS.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2002_MTHS.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2003_MTHS.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2004_MTHS.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2005_MTHS.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2006_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2007_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2008_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2009_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2010_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2011_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2012_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2013_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2014_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2015_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2016_MTH.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2017_MTHS.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\fs2018M.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\FS2019MTHS.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\fs2020.tif
# Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters_v2\fs2020_classified.tif

# %% [markdown]
# ## Working file - cleaning second attempt 8/10/2020

# %%
for shape in shapefile_list:
    shape.strip()
    print(shapefile_list)
    
    # check if the "temp_property" file already exists and delete it if it does.
    tempDir = 'temp_property'       
    try:
        shutil.rmtree(tempDir)

    except:
        print("The following directory was deleted: ", tempDir)

    # create temporary folders
    tempDir = 'temp_property'
    os.makedirs(tempDir)


    #imlist = r"Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters\fire_list.csv"
    shape = shape
    image_name =[]
    image_date =[]
    site_li =[]
    zoneclass =[]
    zoneresults =[]
    property_list = []
    total_laiskey_list = []
    
    dirname = r'D:\Rob\fire\NAFI_fire_rasters'
    endfilename = '.tif'
    scratchDir = r'D:\Rob\fire\NAFI_fire_rasters'

    #def mainRoutine():

    # read in the command arguments
    #cmdargs = getCmdargs()
    imlist = (r'D:\Rob\fire\test_nafi\list_of_files.csv')
    nodata= int(255)
    #shape = cmdargs.shape 
    uid = "uid"
    export_csv = (r'D:\Rob\fire\outputs\20201012_outputs\allTouchFalse')

    # check if the "temp_individual_bands" file already exists and delete it if it does.
    """tempDir = 'temp_individual_bands'       
    try:
        shutil.rmtree(tempDir)

    except:
        print("The following directory was deleted: ", tempDir)"""

    # create temporary folders
    #tempDir = 'temp_individual_bands'
    #os.makedirs(tempDir)

    with open(imlist, "r") as imagerylist:

        #Extract each image path from the image list
        for image in imagerylist:
            #print(image)

            # cleans the file pathway (Windows)
            imageS = image.rstrip()
            #print("imageS: ", imageS)
            im_name = imageS[22:-4]
            print("Im_Name: ", im_name)

            # loops through each image
            with rasterio.open(imageS, nodata= nodata) as srci:
                imageResults = ('image_' + im_name + '.csv')
                print("imageresults", imageResults)
                # runs the zonal stats function and outputs a csv in a band specific folder
                #finalresults = applyZonalstats(imageS, nodata, band, shape, uid)

                """--------------------------------------------------------------------------------------------------------------"""

                #def applyZonalstats(imageS, nodata, band, shape, uid):

                '''image_name =[]
                image_date =[]
                site_li =[]
                zoneclass =[]
                zoneresults =[]'''
                total_uid_list = []
                laiskey_list = []

                with rasterio.open(imageS, nodata=nodata) as srci:
                    print("ImageS: ", imageS)
                    affine = srci.transform #srci.transform is the new srci.affine
                    array = srci.read(1)
                    #print(array)
                    
                    with fiona.open(shape) as src:
                        # using "all_touched=True" will increase the number of pixels used to produce the stats "False" reduces the number
                        print("Shape: ", shape)
                        cmap = {1: 'Jan', 2: 'Feb', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
                        zs = zonal_stats(src, array, affine=affine, stats=['count'],categorical=True, 
                                         category_map=cmap, nodata = nodata , all_touched=False) # , all_touched=False

                        # extract image name and append to list
                        imgName = str(srci)[48:-11]
                        print("imgName: ", imgName)
                        image_name.append(imgName)
                        # extract image date and append to list
                        imgDate = str(imgName)[2:6]
                        print("imgDate: ", imgDate)
                        image_date.append(imgDate)
                        
                        df  = pd.DataFrame.from_records(zs)
                        df.insert(0, 'image', imgName)
                        df.insert(0, 'year', imgDate)
                        
                        for i in src:
                            uid_list = []
                            # extract shapefile records
                            table_attributes = i['properties'] 
                            
                            laiskey_ = table_attributes["LAISKEY"]
                            laiskey_string = str(laiskey_)
                            laiskey_list.append(laiskey_string)
                            total_laiskey_list.append(laiskey_string)
                            #print("TOTAL_UID_LIST as it happens: ", total_uid_list)

                            prop = table_attributes["PROP_NAME"]
                            property_list.append(prop)
                            #print("UID_LIST: ", uid_list)

                            uid_ = table_attributes["uid"]
                            uid_string = str(uid_)
                            uid_list.append(uid_string)
                            total_uid_list.append(uid_string)
                            
                            property_name = shape.rstrip()
                            print("Property name: ", property_name)
                            clean_prop_name = property_name[38:-10]
                            print("Clean_Prop_Name: ", clean_prop_name)
                            df['property'] = clean_prop_name

                    #df["image"] =
                    df['uid_final'] = total_uid_list
                    df['Laiskey'] = laiskey_list
                    #print("TOTAL_UID_LIST: ", total_uid_list)
                    df['band']= 1

                    print("============================================================================")
                    print(df)
                    print("----------------------------------------------------------------------------")
                    print("IMAGE RESULTS: ", imageResults)
                    df.to_csv(tempDir + '//' + imageResults, index=False) 

                    srci.close()

                    # print out the file name of the processed image
                    print (imgName + ' ' + imgDate +  ' ' + 'zone stats are complete')

                    #return(finalresults)

                    """--------------------------------------------------------------------------------------------------------"""

                    #RETURN TO MAIN FUNCTION


                    """property_name = shape.rstrip()
                    print("Property name: ", property_name)
                    clean_prop_name = property_name[98:-4]
                    print("Clean_Prop_Name: ", clean_prop_name)"""


    # for loops through the band folders and concatenates zonal stat outputs into a complete band specific csv   
    band_files = glob.glob(os.path.join(tempDir, "*.csv")) # advisable to use os.path.join as this makes concatenation OS independent
    df_from_each_band_file = (pd.read_csv(f) for f in band_files)
    concat_band_df   = pd.concat(df_from_each_band_file,ignore_index=False, axis=0, sort=False)
    #concat_band_df = concat_band_df.insert(0, 'property', prop)
    # export the band specific results to a csv file (i.e. three outputs)
    concat_band_df.to_csv(export_csv + '\\' + clean_prop_name + "_fire_scar.csv",index=False)
# Out:
# ['D:\\Rob\\fire\\test_properties\\work_comp\\allambi_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\birrimba_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\camfield_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\cattle creek_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\elizabeth downs_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\epenarra_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\hayfield_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\inverway_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\jindare_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\katherine downs_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\killarney_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\mary river west_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\middle creek_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\montejinni east_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\montejinni west_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\murray downs_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\riveren_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\shenandoah_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\shenandoah east_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\todd river_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\wave hill_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\willeroo_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\wongalara_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\tennant creek_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\bullo river_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\yambah_GDA94.shp']
# Im_Name:  FS2000_MTHS
# imageresults image_FS2000_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2000_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2000_MTHS.tif
# imgDate:  2000
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year            image    0.0  count property uid_final        Laiskey  band
# 0  2000  FS2000_MTHS.tif  36910  36910  allambi         1  000     03692     1
# 1  2000  FS2000_MTHS.tif    879    879  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2000_MTHS.csv
# FS2000_MTHS.tif 2000 zone stats are complete
# Im_Name:  FS2001_MTHS
# imageresults image_FS2001_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2001_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2001_MTHS.tif
# imgDate:  2001
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year            image    0.0  count property uid_final        Laiskey  band
# 0  2001  FS2001_MTHS.tif  36910  36910  allambi         1  000     03692     1
# 1  2001  FS2001_MTHS.tif    879    879  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2001_MTHS.csv
# FS2001_MTHS.tif 2001 zone stats are complete
# Im_Name:  FS2002_MTHS
# imageresults image_FS2002_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2002_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2002_MTHS.tif
# imgDate:  2002
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year            image    0.0     Jan     Feb  March  count property  \
# 0  2002  FS2002_MTHS.tif  32922  1151.0  2463.0  374.0  36910  allambi
# 1  2002  FS2002_MTHS.tif    879     NaN     NaN    NaN    879  allambi
#
#   uid_final        Laiskey  band
# 0         1  000     03692     1
# 1         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2002_MTHS.csv
# FS2002_MTHS.tif 2002 zone stats are complete
# Im_Name:  FS2003_MTHS
# imageresults image_FS2003_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2003_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2003_MTHS.tif
# imgDate:  2003
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year            image    0.0     Feb  count property uid_final  \
# 0  2003  FS2003_MTHS.tif  31025  5885.0  36910  allambi         1
# 1  2003  FS2003_MTHS.tif    879     NaN    879  allambi         2
#
#          Laiskey  band
# 0  000     03692     1
# 1  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2003_MTHS.csv
# FS2003_MTHS.tif 2003 zone stats are complete
# Im_Name:  FS2004_MTHS
# imageresults image_FS2004_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2004_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2004_MTHS.tif
# imgDate:  2004
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year            image    0.0  count property uid_final        Laiskey  band
# 0  2004  FS2004_MTHS.tif  36910  36910  allambi         1  000     03692     1
# 1  2004  FS2004_MTHS.tif    879    879  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2004_MTHS.csv
# FS2004_MTHS.tif 2004 zone stats are complete
# Im_Name:  FS2005_MTHS
# imageresults image_FS2005_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2005_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2005_MTHS.tif
# imgDate:  2005
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year            image    0.0  count property uid_final        Laiskey  band
# 0  2005  FS2005_MTHS.tif  36910  36910  allambi         1  000     03692     1
# 1  2005  FS2005_MTHS.tif    879    879  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2005_MTHS.csv
# FS2005_MTHS.tif 2005 zone stats are complete
# Im_Name:  FS2006_MTH
# imageresults image_FS2006_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2006_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2006_MTH.tif
# imgDate:  2006
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image  count property uid_final        Laiskey  band
# 0  2006  FS2006_MTH.tif      0  allambi         1  000     03692     1
# 1  2006  FS2006_MTH.tif      0  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2006_MTH.csv
# FS2006_MTH.tif 2006 zone stats are complete
# Im_Name:  FS2007_MTH
# imageresults image_FS2007_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2007_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2007_MTH.tif
# imgDate:  2007
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image  count property uid_final        Laiskey  band
# 0  2007  FS2007_MTH.tif      0  allambi         1  000     03692     1
# 1  2007  FS2007_MTH.tif      0  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2007_MTH.csv
# FS2007_MTH.tif 2007 zone stats are complete
# Im_Name:  FS2008_MTH
# imageresults image_FS2008_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2008_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2008_MTH.tif
# imgDate:  2008
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2008  FS2008_MTH.tif  36828  36828  allambi         1  000     03692     1
# 1  2008  FS2008_MTH.tif    875    875  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2008_MTH.csv
# FS2008_MTH.tif 2008 zone stats are complete
# Im_Name:  FS2009_MTH
# imageresults image_FS2009_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2009_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2009_MTH.tif
# imgDate:  2009
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image  count property uid_final        Laiskey  band
# 0  2009  FS2009_MTH.tif      0  allambi         1  000     03692     1
# 1  2009  FS2009_MTH.tif      0  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2009_MTH.csv
# FS2009_MTH.tif 2009 zone stats are complete
# Im_Name:  FS2010_MTH
# imageresults image_FS2010_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2010_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2010_MTH.tif
# imgDate:  2010
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image  count property uid_final        Laiskey  band
# 0  2010  FS2010_MTH.tif      0  allambi         1  000     03692     1
# 1  2010  FS2010_MTH.tif      0  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2010_MTH.csv
# FS2010_MTH.tif 2010 zone stats are complete
# Im_Name:  FS2011_MTH
# imageresults image_FS2011_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2011_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2011_MTH.tif
# imgDate:  2011
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image    0.0    Feb      Sep    Oct  Dec  count property  \
# 0  2011  FS2011_MTH.tif  13627  289.0  21699.0  362.0  933  36910  allambi
# 1  2011  FS2011_MTH.tif    773    NaN      NaN    NaN  106    879  allambi
#
#   uid_final        Laiskey  band
# 0         1  000     03692     1
# 1         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2011_MTH.csv
# FS2011_MTH.tif 2011 zone stats are complete
# Im_Name:  FS2012_MTH
# imageresults image_FS2012_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2012_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2012_MTH.tif
# imgDate:  2012
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image  count property uid_final        Laiskey  band
# 0  2012  FS2012_MTH.tif      0  allambi         1  000     03692     1
# 1  2012  FS2012_MTH.tif      0  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2012_MTH.csv
# FS2012_MTH.tif 2012 zone stats are complete
# Im_Name:  FS2013_MTH
# imageresults image_FS2013_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2013_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2013_MTH.tif
# imgDate:  2013
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2013  FS2013_MTH.tif  36906  36906  allambi         1  000     03692     1
# 1  2013  FS2013_MTH.tif    877    877  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2013_MTH.csv
# FS2013_MTH.tif 2013 zone stats are complete
# Im_Name:  FS2014_MTH
# imageresults image_FS2014_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2014_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2014_MTH.tif
# imgDate:  2014
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image    0.0    Sep  count property uid_final  \
# 0  2014  FS2014_MTH.tif  36787  123.0  36910  allambi         1
# 1  2014  FS2014_MTH.tif    879    NaN    879  allambi         2
#
#          Laiskey  band
# 0  000     03692     1
# 1  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2014_MTH.csv
# FS2014_MTH.tif 2014 zone stats are complete
# Im_Name:  FS2015_MTH
# imageresults image_FS2015_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2015_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2015_MTH.tif
# imgDate:  2015
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2015  FS2015_MTH.tif  36910  36910  allambi         1  000     03692     1
# 1  2015  FS2015_MTH.tif    879    879  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2015_MTH.csv
# FS2015_MTH.tif 2015 zone stats are complete
# Im_Name:  FS2016_MTH
# imageresults image_FS2016_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2016_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2016_MTH.tif
# imgDate:  2016
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2016  FS2016_MTH.tif  36824  36824  allambi         1  000     03692     1
# 1  2016  FS2016_MTH.tif    874    874  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2016_MTH.csv
# FS2016_MTH.tif 2016 zone stats are complete
# Im_Name:  FS2017_MTHS
# imageresults image_FS2017_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2017_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2017_MTHS.tif
# imgDate:  2017
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year            image    0.0  count property uid_final        Laiskey  band
# 0  2017  FS2017_MTHS.tif  36910  36910  allambi         1  000     03692     1
# 1  2017  FS2017_MTHS.tif    879    879  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2017_MTHS.csv
# FS2017_MTHS.tif 2017 zone stats are complete
# Im_Name:  fs2018M
# imageresults image_fs2018M.csv
# ImageS:  D:\Rob\fire\test_nafi\fs2018M.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  fs2018M.tif
# imgDate:  2018
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year        image    0.0  count property uid_final        Laiskey  band
# 0  2018  fs2018M.tif  36910  36910  allambi         1  000     03692     1
# 1  2018  fs2018M.tif    879    879  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_fs2018M.csv
# fs2018M.tif 2018 zone stats are complete
# Im_Name:  FS2019MTHS
# imageresults image_FS2019MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2019MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  FS2019MTHS.tif
# imgDate:  2019
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2019  FS2019MTHS.tif  36910  36910  allambi         1  000     03692     1
# 1  2019  FS2019MTHS.tif    879    879  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2019MTHS.csv
# FS2019MTHS.tif 2019 zone stats are complete
# Im_Name:  fs2020
# imageresults image_fs2020.csv
# ImageS:  D:\Rob\fire\test_nafi\fs2020.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  fs2020.tif
# imgDate:  2020
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year       image    0.0  count property uid_final        Laiskey  band
# 0  2020  fs2020.tif  36860  36860  allambi         1  000     03692     1
# 1  2020  fs2020.tif    874    874  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_fs2020.csv
# fs2020.tif 2020 zone stats are complete
# Im_Name:  fs2020_classified
# imageresults image_fs2020_classified.csv
# ImageS:  D:\Rob\fire\test_nafi\fs2020_classified.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# imgName:  fs2020_classified.tif
# imgDate:  2020
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:  allambi
# ============================================================================
#    year                  image  count property uid_final        Laiskey  band
# 0  2020  fs2020_classified.tif      0  allambi         1  000     03692     1
# 1  2020  fs2020_classified.tif      0  allambi         2  000     07517     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_fs2020_classified.csv
# fs2020_classified.tif 2020 zone stats are complete
# ['D:\\Rob\\fire\\test_properties\\work_comp\\allambi_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\birrimba_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\camfield_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\cattle creek_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\elizabeth downs_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\epenarra_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\hayfield_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\inverway_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\jindare_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\katherine downs_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\killarney_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\mary river west_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\middle creek_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\montejinni east_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\montejinni west_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\murray downs_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\riveren_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\shenandoah_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\shenandoah east_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\todd river_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\wave hill_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\willeroo_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\wongalara_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\tennant creek_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\bullo river_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\yambah_GDA94.shp']
# Im_Name:  FS2000_MTHS
# imageresults image_FS2000_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2000_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2000_MTHS.tif
# imgDate:  2000
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year            image    0.0  count  property uid_final        Laiskey  \
# 0  2000  FS2000_MTHS.tif  35346  35346  birrimba         1  000     02666
#
#    band
# 0     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2000_MTHS.csv
# FS2000_MTHS.tif 2000 zone stats are complete
# Im_Name:  FS2001_MTHS
# imageresults image_FS2001_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2001_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2001_MTHS.tif
# imgDate:  2001
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year            image   0.0  April    May  June  Oct  Nov  count  property  \
# 0  2001  FS2001_MTHS.tif  3221    101  24189  6722  132  981  35346  birrimba
#
#   uid_final        Laiskey  band
# 0         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2001_MTHS.csv
# FS2001_MTHS.tif 2001 zone stats are complete
# Im_Name:  FS2002_MTHS
# imageresults image_FS2002_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2002_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2002_MTHS.tif
# imgDate:  2002
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year            image    0.0  April   Oct   Nov   Dec  count  property  \
# 0  2002  FS2002_MTHS.tif  27093     11  1352  5781  1109  35346  birrimba
#
#   uid_final        Laiskey  band
# 0         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2002_MTHS.csv
# FS2002_MTHS.tif 2002 zone stats are complete
# Im_Name:  FS2003_MTHS
# imageresults image_FS2003_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2003_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2003_MTHS.tif
# imgDate:  2003
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year            image    0.0   Nov  count  property uid_final  \
# 0  2003  FS2003_MTHS.tif  30681  4665  35346  birrimba         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2003_MTHS.csv
# FS2003_MTHS.tif 2003 zone stats are complete
# Im_Name:  FS2004_MTHS
# imageresults image_FS2004_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2004_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2004_MTHS.tif
# imgDate:  2004
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year            image   0.0  April   May    Nov   Dec  count  property  \
# 0  2004  FS2004_MTHS.tif  7948   1210  3232  13997  8959  35346  birrimba
#
#   uid_final        Laiskey  band
# 0         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2004_MTHS.csv
# FS2004_MTHS.tif 2004 zone stats are complete
# Im_Name:  FS2005_MTHS
# imageresults image_FS2005_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2005_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2005_MTHS.tif
# imgDate:  2005
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year            image    0.0  May  Nov  count  property uid_final  \
# 0  2005  FS2005_MTHS.tif  34628  183  535  35346  birrimba         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2005_MTHS.csv
# FS2005_MTHS.tif 2005 zone stats are complete
# Im_Name:  FS2006_MTH
# imageresults image_FS2006_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2006_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2006_MTH.tif
# imgDate:  2006
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image  May   Dec  count  property uid_final        Laiskey  \
# 0  2006  FS2006_MTH.tif  206  2916   3122  birrimba         1  000     02666
#
#    band
# 0     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2006_MTH.csv
# FS2006_MTH.tif 2006 zone stats are complete
# Im_Name:  FS2007_MTH
# imageresults image_FS2007_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2007_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2007_MTH.tif
# imgDate:  2007
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image  April   May  Oct    Nov  count  property uid_final  \
# 0  2007  FS2007_MTH.tif      2  1985  129  13476  15592  birrimba         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2007_MTH.csv
# FS2007_MTH.tif 2007 zone stats are complete
# Im_Name:  FS2008_MTH
# imageresults image_FS2008_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2008_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2008_MTH.tif
# imgDate:  2008
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image    0.0   Nov  count  property uid_final  \
# 0  2008  FS2008_MTH.tif  34118  1228  35346  birrimba         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2008_MTH.csv
# FS2008_MTH.tif 2008 zone stats are complete
# Im_Name:  FS2009_MTH
# imageresults image_FS2009_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2009_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2009_MTH.tif
# imgDate:  2009
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image  Aug    Nov    Dec  count  property uid_final  \
# 0  2009  FS2009_MTH.tif    1  16849  11483  28333  birrimba         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2009_MTH.csv
# FS2009_MTH.tif 2009 zone stats are complete
# Im_Name:  FS2010_MTH
# imageresults image_FS2010_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2010_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2010_MTH.tif
# imgDate:  2010
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image  count  property uid_final        Laiskey  band
# 0  2010  FS2010_MTH.tif      0  birrimba         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2010_MTH.csv
# FS2010_MTH.tif 2010 zone stats are complete
# Im_Name:  FS2011_MTH
# imageresults image_FS2011_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2011_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2011_MTH.tif
# imgDate:  2011
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image    0.0    Oct   Nov  count  property uid_final  \
# 0  2011  FS2011_MTH.tif  15460  18110  1776  35346  birrimba         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2011_MTH.csv
# FS2011_MTH.tif 2011 zone stats are complete
# Im_Name:  FS2012_MTH
# imageresults image_FS2012_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2012_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2012_MTH.tif
# imgDate:  2012
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image  Jan  Feb    Sep   Oct  Nov  count  property  \
# 0  2012  FS2012_MTH.tif   45  155  26654  1316  416  28586  birrimba
#
#   uid_final        Laiskey  band
# 0         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2012_MTH.csv
# FS2012_MTH.tif 2012 zone stats are complete
# Im_Name:  FS2013_MTH
# imageresults image_FS2013_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2013_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2013_MTH.tif
# imgDate:  2013
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image    0.0  April  Dec  count  property uid_final  \
# 0  2013  FS2013_MTH.tif  34782     42  523  35347  birrimba         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2013_MTH.csv
# FS2013_MTH.tif 2013 zone stats are complete
# Im_Name:  FS2014_MTH
# imageresults image_FS2014_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2014_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2014_MTH.tif
# imgDate:  2014
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image   0.0  April  May    Sep  Nov  count  property  \
# 0  2014  FS2014_MTH.tif  2856    680  684  31116   10  35346  birrimba
#
#   uid_final        Laiskey  band
# 0         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2014_MTH.csv
# FS2014_MTH.tif 2014 zone stats are complete
# Im_Name:  FS2015_MTH
# imageresults image_FS2015_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2015_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2015_MTH.tif
# imgDate:  2015
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image    0.0  April  May   Sep   Nov  count  property  \
# 0  2015  FS2015_MTH.tif  24617   1753   21  1418  7537  35346  birrimba
#
#   uid_final        Laiskey  band
# 0         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2015_MTH.csv
# FS2015_MTH.tif 2015 zone stats are complete
# Im_Name:  FS2016_MTH
# imageresults image_FS2016_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2016_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2016_MTH.tif
# imgDate:  2016
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image    0.0  March  April  May  Nov  Dec  count  property  \
# 0  2016  FS2016_MTH.tif  29047      3   5370  895    4   42  35361  birrimba
#
#   uid_final        Laiskey  band
# 0         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2016_MTH.csv
# FS2016_MTH.tif 2016 zone stats are complete
# Im_Name:  FS2017_MTHS
# imageresults image_FS2017_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2017_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2017_MTHS.tif
# imgDate:  2017
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year            image    0.0  April  May  June   Nov  Dec  count  property  \
# 0  2017  FS2017_MTHS.tif  21238   9696  643    27  3330  412  35346  birrimba
#
#   uid_final        Laiskey  band
# 0         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2017_MTHS.csv
# FS2017_MTHS.tif 2017 zone stats are complete
# Im_Name:  fs2018M
# imageresults image_fs2018M.csv
# ImageS:  D:\Rob\fire\test_nafi\fs2018M.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  fs2018M.tif
# imgDate:  2018
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year        image    0.0  Jan  April  Oct  Nov   Dec  count  property  \
# 0  2018  fs2018M.tif  24029  469   7129  423  120  3176  35346  birrimba
#
#   uid_final        Laiskey  band
# 0         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_fs2018M.csv
# fs2018M.tif 2018 zone stats are complete
# Im_Name:  FS2019MTHS
# imageresults image_FS2019MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2019MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  FS2019MTHS.tif
# imgDate:  2019
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year           image    0.0  Jan  Feb  count  property uid_final  \
# 0  2019  FS2019MTHS.tif  35114  135   97  35346  birrimba         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2019MTHS.csv
# FS2019MTHS.tif 2019 zone stats are complete
# Im_Name:  fs2020
# imageresults image_fs2020.csv
# ImageS:  D:\Rob\fire\test_nafi\fs2020.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  fs2020.tif
# imgDate:  2020
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year       image    0.0  count  property uid_final        Laiskey  band
# 0  2020  fs2020.tif  35352  35352  birrimba         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_fs2020.csv
# fs2020.tif 2020 zone stats are complete
# Im_Name:  fs2020_classified
# imageresults image_fs2020_classified.csv
# ImageS:  D:\Rob\fire\test_nafi\fs2020_classified.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# imgName:  fs2020_classified.tif
# imgDate:  2020
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:  birrimba
# ============================================================================
#    year                  image  count  property uid_final        Laiskey  band
# 0  2020  fs2020_classified.tif      0  birrimba         1  000     02666     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_fs2020_classified.csv
# fs2020_classified.tif 2020 zone stats are complete
# ['D:\\Rob\\fire\\test_properties\\work_comp\\allambi_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\birrimba_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\camfield_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\cattle creek_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\elizabeth downs_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\epenarra_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\hayfield_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\inverway_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\jindare_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\katherine downs_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\killarney_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\mary river west_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\middle creek_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\montejinni east_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\montejinni west_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\murray downs_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\riveren_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\shenandoah_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\shenandoah east_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\todd river_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\wave hill_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\willeroo_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\wongalara_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\tennant creek_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\bullo river_GDA94.shp', 'D:\\Rob\\fire\\test_properties\\work_comp\\yambah_GDA94.shp']
# Im_Name:  FS2000_MTHS
# imageresults image_FS2000_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2000_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# imgName:  FS2000_MTHS.tif
# imgDate:  2000
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:  camfield
# ============================================================================
#    year            image    0.0   Oct  Nov  count  property uid_final  \
# 0  2000  FS2000_MTHS.tif  29010  7776  799  37585  camfield         1
#
#          Laiskey  band
# 0  000     03736     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2000_MTHS.csv
# FS2000_MTHS.tif 2000 zone stats are complete
# Im_Name:  FS2001_MTHS
# imageresults image_FS2001_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2001_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# imgName:  FS2001_MTHS.tif
# imgDate:  2001
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:  camfield
# ============================================================================
#    year            image    0.0  April  June  July  Aug   Sep   Oct  count  \
# 0  2001  FS2001_MTHS.tif  25917     23     9   392    8  4301  6935  37585
#
#    property uid_final        Laiskey  band
# 0  camfield         1  000     03736     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2001_MTHS.csv
# FS2001_MTHS.tif 2001 zone stats are complete
# Im_Name:  FS2002_MTHS
# imageresults image_FS2002_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2002_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# imgName:  FS2002_MTHS.tif
# imgDate:  2002
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:  camfield
# ============================================================================
#    year            image    0.0  March  May    Oct  Nov  Dec  count  property  \
# 0  2002  FS2002_MTHS.tif  24499    140  403  11387  621  535  37585  camfield
#
#   uid_final        Laiskey  band
# 0         1  000     03736     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2002_MTHS.csv
# FS2002_MTHS.tif 2002 zone stats are complete
# Im_Name:  FS2003_MTHS
# imageresults image_FS2003_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2003_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# imgName:  FS2003_MTHS.tif
# imgDate:  2003
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:  camfield
# ============================================================================
#    year            image    0.0  count  property uid_final        Laiskey  \
# 0  2003  FS2003_MTHS.tif  37585  37585  camfield         1  000     03736
#
#    band
# 0     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2003_MTHS.csv
# FS2003_MTHS.tif 2003 zone stats are complete
# Im_Name:  FS2004_MTHS
# imageresults image_FS2004_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2004_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# imgName:  FS2004_MTHS.tif
# imgDate:  2004
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:  camfield
# ============================================================================
#    year            image    0.0  April  May  July  Aug   Oct   Nov  Dec  \
# 0  2004  FS2004_MTHS.tif  28502    420  476     3  148  6195  1814   27
#
#    count  property uid_final        Laiskey  band
# 0  37585  camfield         1  000     03736     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2004_MTHS.csv
# FS2004_MTHS.tif 2004 zone stats are complete
# Im_Name:  FS2005_MTHS
# imageresults image_FS2005_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2005_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# imgName:  FS2005_MTHS.tif
# imgDate:  2005
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:  camfield
# ============================================================================
#    year            image    0.0  April  count  property uid_final  \
# 0  2005  FS2005_MTHS.tif  37584      1  37585  camfield         1
#
#          Laiskey  band
# 0  000     03736     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2005_MTHS.csv
# FS2005_MTHS.tif 2005 zone stats are complete
# Im_Name:  FS2006_MTH
# imageresults image_FS2006_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2006_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# imgName:  FS2006_MTH.tif
# imgDate:  2006
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:  camfield
# ============================================================================
#    year           image  May  Sep   Nov  count  property uid_final  \
# 0  2006  FS2006_MTH.tif  344   33  9511   9888  camfield         1
#
#          Laiskey  band
# 0  000     03736     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2006_MTH.csv
# FS2006_MTH.tif 2006 zone stats are complete
# Im_Name:  FS2007_MTH
# imageresults image_FS2007_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2007_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# imgName:  FS2007_MTH.tif
# imgDate:  2007
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:  camfield
# ============================================================================
#    year           image  May  Oct  Dec  count  property uid_final  \
# 0  2007  FS2007_MTH.tif    1  846  847   1694  camfield         1
#
#          Laiskey  band
# 0  000     03736     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2007_MTH.csv
# FS2007_MTH.tif 2007 zone stats are complete
# Im_Name:  FS2008_MTH
# imageresults image_FS2008_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2008_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# imgName:  FS2008_MTH.tif
# imgDate:  2008
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:  camfield
# ============================================================================
#    year           image    0.0  April  May  July  Dec  count  property  \
# 0  2008  FS2008_MTH.tif  36399   1219    5     1   32  37656  camfield
#
#   uid_final        Laiskey  band
# 0         1  000     03736     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2008_MTH.csv
# FS2008_MTH.tif 2008 zone stats are complete
# Im_Name:  FS2009_MTH
# imageresults image_FS2009_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2009_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# imgName:  FS2009_MTH.tif
# imgDate:  2009
# ...
# Im_Name:  FS2000_MTHS
# imageresults image_FS2000_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2000_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2000_MTHS.tif
# imgDate:  2000
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year            image    0.0  count property uid_final        Laiskey  band
# 0  2000  FS2000_MTHS.tif  32414  32414   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2000_MTHS.csv
# FS2000_MTHS.tif 2000 zone stats are complete
# Im_Name:  FS2001_MTHS
# imageresults image_FS2001_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2001_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2001_MTHS.tif
# imgDate:  2001
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year            image    0.0  Sep  count property uid_final        Laiskey  \
# 0  2001  FS2001_MTHS.tif  32048  366  32414   yambah         1  000     00641
#
#    band
# 0     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2001_MTHS.csv
# FS2001_MTHS.tif 2001 zone stats are complete
# Im_Name:  FS2002_MTHS
# imageresults image_FS2002_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2002_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2002_MTHS.tif
# imgDate:  2002
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year            image    0.0  July   Nov   Dec  count property uid_final  \
# 0  2002  FS2002_MTHS.tif  28074    35  2330  1975  32414   yambah         1
#
#          Laiskey  band
# 0  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2002_MTHS.csv
# FS2002_MTHS.tif 2002 zone stats are complete
# Im_Name:  FS2003_MTHS
# imageresults image_FS2003_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2003_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2003_MTHS.tif
# imgDate:  2003
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year            image    0.0  count property uid_final        Laiskey  band
# 0  2003  FS2003_MTHS.tif  32414  32414   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2003_MTHS.csv
# FS2003_MTHS.tif 2003 zone stats are complete
# Im_Name:  FS2004_MTHS
# imageresults image_FS2004_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2004_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2004_MTHS.tif
# imgDate:  2004
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year            image    0.0  count property uid_final        Laiskey  band
# 0  2004  FS2004_MTHS.tif  32414  32414   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2004_MTHS.csv
# FS2004_MTHS.tif 2004 zone stats are complete
# Im_Name:  FS2005_MTHS
# imageresults image_FS2005_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2005_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2005_MTHS.tif
# imgDate:  2005
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year            image    0.0  count property uid_final        Laiskey  band
# 0  2005  FS2005_MTHS.tif  32414  32414   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2005_MTHS.csv
# FS2005_MTHS.tif 2005 zone stats are complete
# Im_Name:  FS2006_MTH
# imageresults image_FS2006_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2006_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2006_MTH.tif
# imgDate:  2006
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image  count property uid_final        Laiskey  band
# 0  2006  FS2006_MTH.tif      0   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2006_MTH.csv
# FS2006_MTH.tif 2006 zone stats are complete
# Im_Name:  FS2007_MTH
# imageresults image_FS2007_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2007_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2007_MTH.tif
# imgDate:  2007
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image  count property uid_final        Laiskey  band
# 0  2007  FS2007_MTH.tif      0   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2007_MTH.csv
# FS2007_MTH.tif 2007 zone stats are complete
# Im_Name:  FS2008_MTH
# imageresults image_FS2008_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2008_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2008_MTH.tif
# imgDate:  2008
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2008  FS2008_MTH.tif  32336  32336   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2008_MTH.csv
# FS2008_MTH.tif 2008 zone stats are complete
# Im_Name:  FS2009_MTH
# imageresults image_FS2009_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2009_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2009_MTH.tif
# imgDate:  2009
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image  count property uid_final        Laiskey  band
# 0  2009  FS2009_MTH.tif      0   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2009_MTH.csv
# FS2009_MTH.tif 2009 zone stats are complete
# Im_Name:  FS2010_MTH
# imageresults image_FS2010_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2010_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2010_MTH.tif
# imgDate:  2010
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image  count property uid_final        Laiskey  band
# 0  2010  FS2010_MTH.tif      0   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2010_MTH.csv
# FS2010_MTH.tif 2010 zone stats are complete
# Im_Name:  FS2011_MTH
# imageresults image_FS2011_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2011_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2011_MTH.tif
# imgDate:  2011
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image    0.0  July  Aug   Sep   Oct  count property  \
# 0  2011  FS2011_MTH.tif  19029   277   14  9743  3351  32414   yambah
#
#   uid_final        Laiskey  band
# 0         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2011_MTH.csv
# FS2011_MTH.tif 2011 zone stats are complete
# Im_Name:  FS2012_MTH
# imageresults image_FS2012_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2012_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2012_MTH.tif
# imgDate:  2012
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image  July   Nov  count property uid_final        Laiskey  \
# 0  2012  FS2012_MTH.tif     8  3416   3424   yambah         1  000     00641
#
#    band
# 0     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2012_MTH.csv
# FS2012_MTH.tif 2012 zone stats are complete
# Im_Name:  FS2013_MTH
# imageresults image_FS2013_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2013_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2013_MTH.tif
# imgDate:  2013
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2013  FS2013_MTH.tif  32403  32403   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2013_MTH.csv
# FS2013_MTH.tif 2013 zone stats are complete
# Im_Name:  FS2014_MTH
# imageresults image_FS2014_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2014_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2014_MTH.tif
# imgDate:  2014
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2014  FS2014_MTH.tif  32414  32414   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2014_MTH.csv
# FS2014_MTH.tif 2014 zone stats are complete
# Im_Name:  FS2015_MTH
# imageresults image_FS2015_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2015_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2015_MTH.tif
# imgDate:  2015
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2015  FS2015_MTH.tif  32414  32414   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2015_MTH.csv
# FS2015_MTH.tif 2015 zone stats are complete
# Im_Name:  FS2016_MTH
# imageresults image_FS2016_MTH.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2016_MTH.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2016_MTH.tif
# imgDate:  2016
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2016  FS2016_MTH.tif  32465  32465   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2016_MTH.csv
# FS2016_MTH.tif 2016 zone stats are complete
# Im_Name:  FS2017_MTHS
# imageresults image_FS2017_MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2017_MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2017_MTHS.tif
# imgDate:  2017
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year            image    0.0  April  count property uid_final  \
# 0  2017  FS2017_MTHS.tif  32280    134  32414   yambah         1
#
#          Laiskey  band
# 0  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2017_MTHS.csv
# FS2017_MTHS.tif 2017 zone stats are complete
# Im_Name:  fs2018M
# imageresults image_fs2018M.csv
# ImageS:  D:\Rob\fire\test_nafi\fs2018M.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  fs2018M.tif
# imgDate:  2018
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year        image    0.0  count property uid_final        Laiskey  band
# 0  2018  fs2018M.tif  32414  32414   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_fs2018M.csv
# fs2018M.tif 2018 zone stats are complete
# Im_Name:  FS2019MTHS
# imageresults image_FS2019MTHS.csv
# ImageS:  D:\Rob\fire\test_nafi\FS2019MTHS.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  FS2019MTHS.tif
# imgDate:  2019
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year           image    0.0  count property uid_final        Laiskey  band
# 0  2019  FS2019MTHS.tif  32414  32414   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_FS2019MTHS.csv
# FS2019MTHS.tif 2019 zone stats are complete
# Im_Name:  fs2020
# imageresults image_fs2020.csv
# ImageS:  D:\Rob\fire\test_nafi\fs2020.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  fs2020.tif
# imgDate:  2020
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year       image    0.0  count property uid_final        Laiskey  band
# 0  2020  fs2020.tif  32373  32373   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_fs2020.csv
# fs2020.tif 2020 zone stats are complete
# Im_Name:  fs2020_classified
# imageresults image_fs2020_classified.csv
# ImageS:  D:\Rob\fire\test_nafi\fs2020_classified.tif
# Shape:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# imgName:  fs2020_classified.tif
# imgDate:  2020
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:  yambah
# ============================================================================
#    year                  image  count property uid_final        Laiskey  band
# 0  2020  fs2020_classified.tif      0   yambah         1  000     00641     1
# ----------------------------------------------------------------------------
# IMAGE RESULTS:  image_fs2020_classified.csv
# fs2020_classified.tif 2020 zone stats are complete

# %%
import pandas as pd
df = pd.read_csv(r"D:\Rob\fire\outputs\output1\allTouchFalse\wave hill_fire_scar.csv")

# %%
df

# %% [markdown]
# ##Second attempt 8/10/2020 edit

# %% [markdown]
# Created lists for uid but still there are issues.

# %% [markdown]
# # This is working accross all shapefiles and has not been cleaned.

# %%
for shape in shapefile_list:
    shape.strip()
    
    # check if the "temp_individual_bands" file already exists and delete it if it does.
    tempDir = 'temp_individual_bands'       
    try:
        shutil.rmtree(tempDir)

    except:
        print("The following directory was deleted: ", tempDir)

    # create temporary folders
    tempDir = 'temp_individual_bands'
    os.makedirs(tempDir)


    def listdir(dirname,endfilename,scratchDir):
        """
        this function will return a list of files in a directory for the given file extention "endfilename". 
        """
        list_img = []

        for root, dirs, files in os.walk(dirname):
            for file in files:
                if file.endswith(endfilename):
                    img = (os.path.join(root, file))
                    list_img.append(img)
                    #print (img)
                    #shutil.copy(os.path.abspath(img), scratchDir)
        #print("Script has finished")
        return list_img

    dirname = r'U:\Working\Rangelands\Spatial Data\NAFI Firescars'
    endfilename = 'MTH.tif'
    scratchDir = r'C:\Users\rmcgr\Desktop\firemaps\scratch'

    listdir(dirname,endfilename,scratchDir)



    imlist = r"Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters\fire_list.csv"
    shape = shape
    image_name =[]
    image_date =[]
    site_li =[]
    zoneclass =[]
    zoneresults =[]
    
    property_list = []



    #def mainRoutine():

    # read in the command arguments
    """cmdargs = getCmdargs()
    imlist = cmdargs.imlist
    nodata= int(cmdargs.nodata)
    shape = cmdargs.shape 
    uid = cmdargs.uid
    export_csv = cmdargs.csv""" 

    # check if the "temp_individual_bands" file already exists and delete it if it does.
    """tempDir = 'temp_individual_bands'       
    try:
        shutil.rmtree(tempDir)

    except:
        print("The following directory was deleted: ", tempDir)"""

    # create temporary folders
    #tempDir = 'temp_individual_bands'
    #os.makedirs(tempDir)

    with open(imlist, "r") as imagerylist:

        #Extract each image path from the image list
        for image in imagerylist:
            #print(image)

            # cleans the file pathway (Windows)
            imageS = image.rstrip()
            #print("imageS: ", imageS)
            im_name = imageS[60:]
            #print("Im_Name: ", im_name)

            # loops through each image
            with rasterio.open(imageS, nodata= 0) as srci:
                imageResults = 'image_' + im_name + '.csv'
                # runs the zonal stats function and outputs a csv in a band specific folder
                #finalresults = applyZonalstats(imageS, nodata, band, shape, uid)

                """--------------------------------------------------------------------------------------------------------------"""

                #def applyZonalstats(imageS, nodata, band, shape, uid):

                '''image_name =[]
                image_date =[]
                site_li =[]
                zoneclass =[]
                zoneresults =[]'''
                total_uid_list = []
                laiskey_list = []

                with rasterio.open(imageS, nodata=0) as srci:
                    affine = srci.transform #srci.transform is the new srci.affine
                    array = srci.read(1)
                    #print(array)
                    
                    

                    with fiona.open(shape) as src:
                        # using "all_touched=True" will increase the number of pixels used to produce the stats "False" reduces the number

                        cmap = {1: 'Jan', 2: 'Feb', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
                        zs = zonal_stats(src, array, affine=affine, stats=['count'],categorical=True, 
                                         category_map=cmap, nodata = 0, all_touched=False)

                        # extract image name and append to list
                        imgName = str(srci)[86:-11]
                        #print("imgName: ", imgName)
                        image_name.append(imgName)
                        # extract image date and append to list
                        imgDate = str(imgName)[2:6]
                        #print("imgDate: ", imgDate)
                        image_date.append(imgDate)
                        
                        df  = pd.DataFrame.from_records(zs)
                        df.insert(0, 'image', imgName)
                        df.insert(0, 'year', imgDate)
                        
                        for i in src:
                            uid_list = []
                            # extract shapefile records
                            table_attributes = i['properties'] 
                            
                            laiskey_ = table_attributes["LAISKEY"]
                            laiskey_string = str(laiskey_)
                            laiskey_list.append(laiskey_string)
                            total_laiskey_list.append(laiskey_string)
                            print("TOTAL_UID_LIST as it happens: ", total_uid_list)

                            prop = table_attributes["PROP_NAME"]
                            property_list.append(prop)
                            print("UID_LIST: ", uid_list)
                            #df['uid_test'] = uid_
                            
                            uid_ = table_attributes["uid"]
                            uid_string = str(uid_)
                            uid_list.append(uid_string)
                            total_uid_list.append(uid_string)

                        
                        print("============================================================================")
                        print(df)
                        print("----------------------------------------------------------------------------")

                    df['uid_final'] = total_uid_list
                    df['Laiskey'] = laiskey_list
                    print("TOTAL_UID_LIST: ", total_uid_list)
                    #df['site____'].append(total_uid_string)
                    df['band']= 1
                    print("============================================================================")
                    print("nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn")
                    print(df)
                    print("----------------------------------------------------------------------------")
                    df.to_csv(tempDir + '//' + imageResults, index=False) 

                    srci.close()

                    # print out the file name of the processed image
                    print (imgName + ' ' + imgDate +  ' ' + 'zone stats are complete')

                    #return(finalresults)

                    """--------------------------------------------------------------------------------------------------------"""

                    #RETURN TO MAIN FUNCTION


                    property_name = shape.rstrip()
                    print("Property name: ", property_name)
                    clean_prop_name = property_name[98:-4]
                    print("Clean_Prop_Name: ", clean_prop_name)


    # for loops through the band folders and concatenates zonal stat outputs into a complete band specific csv   
    band_files = glob.glob(os.path.join(tempDir, "*.csv")) # advisable to use os.path.join as this makes concatenation OS independent
    df_from_each_band_file = (pd.read_csv(f) for f in band_files)
    concat_band_df   = pd.concat(df_from_each_band_file,ignore_index=False, axis=0, sort=False)
    #concat_band_df = concat_band_df.insert(0, 'property', prop)
    # export the band specific results to a csv file (i.e. three outputs)
    concat_band_df.to_csv(r"\\pgb-bas01\DENR_Satellite_Imagery$\Scratch\Zonal_Stats_Pipeline\Firescars\outputs" + '\\' + clean_prop_name + "_fire_scar.csv",index=False)
# Out:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year            image  count
# 0  2000  FS2000_MTHS.tif      0
# 1  2000  FS2000_MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  count uid_final        Laiskey  band
# 0  2000  FS2000_MTHS.tif      0         1  000     03692     1
# 1  2000  FS2000_MTHS.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2000_MTHS.tif 2000 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year            image  count
# 0  2001  FS2001_MTHS.tif      0
# 1  2001  FS2001_MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  count uid_final        Laiskey  band
# 0  2001  FS2001_MTHS.tif      0         1  000     03692     1
# 1  2001  FS2001_MTHS.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2001_MTHS.tif 2001 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year            image     Jan     Feb  March  count
# 0  2002  FS2002_MTHS.tif  1151.0  2463.0  374.0   3988
# 1  2002  FS2002_MTHS.tif     NaN     NaN    NaN      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image     Jan     Feb  March  count uid_final  \
# 0  2002  FS2002_MTHS.tif  1151.0  2463.0  374.0   3988         1
# 1  2002  FS2002_MTHS.tif     NaN     NaN    NaN      0         2
#
#          Laiskey  band
# 0  000     03692     1
# 1  000     07517     1
# ----------------------------------------------------------------------------
# FS2002_MTHS.tif 2002 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year            image     Feb  count
# 0  2003  FS2003_MTHS.tif  5885.0   5885
# 1  2003  FS2003_MTHS.tif     NaN      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image     Feb  count uid_final        Laiskey  band
# 0  2003  FS2003_MTHS.tif  5885.0   5885         1  000     03692     1
# 1  2003  FS2003_MTHS.tif     NaN      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2003_MTHS.tif 2003 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year            image  count
# 0  2004  FS2004_MTHS.tif      0
# 1  2004  FS2004_MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  count uid_final        Laiskey  band
# 0  2004  FS2004_MTHS.tif      0         1  000     03692     1
# 1  2004  FS2004_MTHS.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2004_MTHS.tif 2004 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year            image  count
# 0  2005  FS2005_MTHS.tif      0
# 1  2005  FS2005_MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  count uid_final        Laiskey  band
# 0  2005  FS2005_MTHS.tif      0         1  000     03692     1
# 1  2005  FS2005_MTHS.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2005_MTHS.tif 2005 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image  255.0  count
# 0  2006  FS2006_MTH.tif  36917  36917
# 1  2006  FS2006_MTH.tif    888    888
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  255.0  count uid_final        Laiskey  band
# 0  2006  FS2006_MTH.tif  36917  36917         1  000     03692     1
# 1  2006  FS2006_MTH.tif    888    888         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2006_MTH.tif 2006 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image  255.0  count
# 0  2007  FS2007_MTH.tif  36910  36910
# 1  2007  FS2007_MTH.tif    879    879
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  255.0  count uid_final        Laiskey  band
# 0  2007  FS2007_MTH.tif  36910  36910         1  000     03692     1
# 1  2007  FS2007_MTH.tif    879    879         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2007_MTH.tif 2007 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2008  FS2008_MTH.tif      0
# 1  2008  FS2008_MTH.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2008  FS2008_MTH.tif      0         1  000     03692     1
# 1  2008  FS2008_MTH.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2008_MTH.tif 2008 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image  255.0  count
# 0  2009  FS2009_MTH.tif  36884  36884
# 1  2009  FS2009_MTH.tif    888    888
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  255.0  count uid_final        Laiskey  band
# 0  2009  FS2009_MTH.tif  36884  36884         1  000     03692     1
# 1  2009  FS2009_MTH.tif    888    888         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2009_MTH.tif 2009 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image  255.0  count
# 0  2010  FS2010_MTH.tif  36794  36794
# 1  2010  FS2010_MTH.tif    893    893
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  255.0  count uid_final        Laiskey  band
# 0  2010  FS2010_MTH.tif  36794  36794         1  000     03692     1
# 1  2010  FS2010_MTH.tif    893    893         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2010_MTH.tif 2010 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image    Feb      Sep    Oct  Dec  count
# 0  2011  FS2011_MTH.tif  289.0  21699.0  362.0  933  23283
# 1  2011  FS2011_MTH.tif    NaN      NaN    NaN  106    106
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image    Feb      Sep    Oct  Dec  count uid_final  \
# 0  2011  FS2011_MTH.tif  289.0  21699.0  362.0  933  23283         1
# 1  2011  FS2011_MTH.tif    NaN      NaN    NaN  106    106         2
#
#          Laiskey  band
# 0  000     03692     1
# 1  000     07517     1
# ----------------------------------------------------------------------------
# FS2011_MTH.tif 2011 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image  255.0  count
# 0  2012  FS2012_MTH.tif  36910  36910
# 1  2012  FS2012_MTH.tif    879    879
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  255.0  count uid_final        Laiskey  band
# 0  2012  FS2012_MTH.tif  36910  36910         1  000     03692     1
# 1  2012  FS2012_MTH.tif    879    879         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2012_MTH.tif 2012 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2013  FS2013_MTH.tif      0
# 1  2013  FS2013_MTH.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2013  FS2013_MTH.tif      0         1  000     03692     1
# 1  2013  FS2013_MTH.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2013_MTH.tif 2013 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image    Sep  count
# 0  2014  FS2014_MTH.tif  123.0    123
# 1  2014  FS2014_MTH.tif    NaN      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image    Sep  count uid_final        Laiskey  band
# 0  2014  FS2014_MTH.tif  123.0    123         1  000     03692     1
# 1  2014  FS2014_MTH.tif    NaN      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2014_MTH.tif 2014 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2015  FS2015_MTH.tif      0
# 1  2015  FS2015_MTH.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2015  FS2015_MTH.tif      0         1  000     03692     1
# 1  2015  FS2015_MTH.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2015_MTH.tif 2015 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2016  FS2016_MTH.tif      0
# 1  2016  FS2016_MTH.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2016  FS2016_MTH.tif      0         1  000     03692     1
# 1  2016  FS2016_MTH.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2016_MTH.tif 2016 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year            image  count
# 0  2017  FS2017_MTHS.tif      0
# 1  2017  FS2017_MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  count uid_final        Laiskey  band
# 0  2017  FS2017_MTHS.tif      0         1  000     03692     1
# 1  2017  FS2017_MTHS.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2017_MTHS.tif 2017 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year        image  count
# 0  2018  fs2018M.tif      0
# 1  2018  fs2018M.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year        image  count uid_final        Laiskey  band
# 0  2018  fs2018M.tif      0         1  000     03692     1
# 1  2018  fs2018M.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# fs2018M.tif 2018 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2019  FS2019MTHS.tif      0
# 1  2019  FS2019MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2019  FS2019MTHS.tif      0         1  000     03692     1
# 1  2019  FS2019MTHS.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# FS2019MTHS.tif 2019 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# TOTAL_UID_LIST as it happens:  ['1']
# UID_LIST:  []
# ============================================================================
#    year       image  count
# 0  2020  fs2020.tif      0
# 1  2020  fs2020.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1', '2']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year       image  count uid_final        Laiskey  band
# 0  2020  fs2020.tif      0         1  000     03692     1
# 1  2020  fs2020.tif      0         2  000     07517     1
# ----------------------------------------------------------------------------
# fs2020.tif 2020 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\allambi_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  count
# 0  2000  FS2000_MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  count uid_final        Laiskey  band
# 0  2000  FS2000_MTHS.tif      0         1  000     02666     1
# ----------------------------------------------------------------------------
# FS2000_MTHS.tif 2000 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  April    May  June  Oct  Nov  count
# 0  2001  FS2001_MTHS.tif    101  24189  6722  132  981  32125
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  April    May  June  Oct  Nov  count uid_final  \
# 0  2001  FS2001_MTHS.tif    101  24189  6722  132  981  32125         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# FS2001_MTHS.tif 2001 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  April   Oct   Nov   Dec  count
# 0  2002  FS2002_MTHS.tif     11  1352  5781  1109   8253
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  April   Oct   Nov   Dec  count uid_final  \
# 0  2002  FS2002_MTHS.tif     11  1352  5781  1109   8253         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# FS2002_MTHS.tif 2002 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image   Nov  count
# 0  2003  FS2003_MTHS.tif  4665   4665
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image   Nov  count uid_final        Laiskey  band
# 0  2003  FS2003_MTHS.tif  4665   4665         1  000     02666     1
# ----------------------------------------------------------------------------
# FS2003_MTHS.tif 2003 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  April   May    Nov   Dec  count
# 0  2004  FS2004_MTHS.tif   1210  3232  13997  8959  27398
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  April   May    Nov   Dec  count uid_final  \
# 0  2004  FS2004_MTHS.tif   1210  3232  13997  8959  27398         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# FS2004_MTHS.tif 2004 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  May  Nov  count
# 0  2005  FS2005_MTHS.tif  183  535    718
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  May  Nov  count uid_final        Laiskey  band
# 0  2005  FS2005_MTHS.tif  183  535    718         1  000     02666     1
# ----------------------------------------------------------------------------
# FS2005_MTHS.tif 2005 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  May   Dec  255.0  count
# 0  2006  FS2006_MTH.tif  206  2916  32402  35524
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  May   Dec  255.0  count uid_final        Laiskey  \
# 0  2006  FS2006_MTH.tif  206  2916  32402  35524         1  000     02666
#
#    band
# 0     1
# ----------------------------------------------------------------------------
# FS2006_MTH.tif 2006 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  April   May  Oct    Nov  255.0  count
# 0  2007  FS2007_MTH.tif      2  1985  129  13476  19754  35346
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  April   May  Oct    Nov  255.0  count uid_final  \
# 0  2007  FS2007_MTH.tif      2  1985  129  13476  19754  35346         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# FS2007_MTH.tif 2007 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image   Nov  count
# 0  2008  FS2008_MTH.tif  1228   1228
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image   Nov  count uid_final        Laiskey  band
# 0  2008  FS2008_MTH.tif  1228   1228         1  000     02666     1
# ----------------------------------------------------------------------------
# FS2008_MTH.tif 2008 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  Aug    Nov    Dec  255.0  count
# 0  2009  FS2009_MTH.tif    1  16849  11483   7101  35434
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  Aug    Nov    Dec  255.0  count uid_final  \
# 0  2009  FS2009_MTH.tif    1  16849  11483   7101  35434         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# FS2009_MTH.tif 2009 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  255.0  count
# 0  2010  FS2010_MTH.tif  35595  35595
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  255.0  count uid_final        Laiskey  band
# 0  2010  FS2010_MTH.tif  35595  35595         1  000     02666     1
# ----------------------------------------------------------------------------
# FS2010_MTH.tif 2010 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image    Oct   Nov  count
# 0  2011  FS2011_MTH.tif  18110  1776  19886
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image    Oct   Nov  count uid_final        Laiskey  band
# 0  2011  FS2011_MTH.tif  18110  1776  19886         1  000     02666     1
# ----------------------------------------------------------------------------
# FS2011_MTH.tif 2011 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  Jan  Feb    Sep   Oct  Nov  255.0  count
# 0  2012  FS2012_MTH.tif   45  155  26654  1316  416   6760  35346
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  Jan  Feb    Sep   Oct  Nov  255.0  count uid_final  \
# 0  2012  FS2012_MTH.tif   45  155  26654  1316  416   6760  35346         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# FS2012_MTH.tif 2012 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  April  Dec  count
# 0  2013  FS2013_MTH.tif     42  523    565
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  April  Dec  count uid_final        Laiskey  band
# 0  2013  FS2013_MTH.tif     42  523    565         1  000     02666     1
# ----------------------------------------------------------------------------
# FS2013_MTH.tif 2013 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  April  May    Sep  Nov  count
# 0  2014  FS2014_MTH.tif    680  684  31116   10  32490
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  April  May    Sep  Nov  count uid_final  \
# 0  2014  FS2014_MTH.tif    680  684  31116   10  32490         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# FS2014_MTH.tif 2014 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  April  May   Sep   Nov  count
# 0  2015  FS2015_MTH.tif   1753   21  1418  7537  10729
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  April  May   Sep   Nov  count uid_final  \
# 0  2015  FS2015_MTH.tif   1753   21  1418  7537  10729         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# FS2015_MTH.tif 2015 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  March  April  May  Nov  Dec  count
# 0  2016  FS2016_MTH.tif      3   5370  895    4   42   6314
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  March  April  May  Nov  Dec  count uid_final  \
# 0  2016  FS2016_MTH.tif      3   5370  895    4   42   6314         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# FS2016_MTH.tif 2016 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  April  May  June   Nov  Dec  count
# 0  2017  FS2017_MTHS.tif   9696  643    27  3330  412  14108
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  April  May  June   Nov  Dec  count uid_final  \
# 0  2017  FS2017_MTHS.tif   9696  643    27  3330  412  14108         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# FS2017_MTHS.tif 2017 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year        image  Jan  April  Oct  Nov   Dec  count
# 0  2018  fs2018M.tif  469   7129  423  120  3176  11317
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year        image  Jan  April  Oct  Nov   Dec  count uid_final  \
# 0  2018  fs2018M.tif  469   7129  423  120  3176  11317         1
#
#          Laiskey  band
# 0  000     02666     1
# ----------------------------------------------------------------------------
# fs2018M.tif 2018 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  Jan  Feb  count
# 0  2019  FS2019MTHS.tif  135   97    232
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  Jan  Feb  count uid_final        Laiskey  band
# 0  2019  FS2019MTHS.tif  135   97    232         1  000     02666     1
# ----------------------------------------------------------------------------
# FS2019MTHS.tif 2019 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year       image  count
# 0  2020  fs2020.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year       image  count uid_final        Laiskey  band
# 0  2020  fs2020.tif      0         1  000     02666     1
# ----------------------------------------------------------------------------
# fs2020.tif 2020 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\birrimba_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image   Oct  Nov  count
# 0  2000  FS2000_MTHS.tif  7776  799   8575
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image   Oct  Nov  count uid_final        Laiskey  band
# 0  2000  FS2000_MTHS.tif  7776  799   8575         1  000     03736     1
# ----------------------------------------------------------------------------
# FS2000_MTHS.tif 2000 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  April  June  July  Aug   Sep   Oct  count
# 0  2001  FS2001_MTHS.tif     23     9   392    8  4301  6935  11668
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  April  June  July  Aug   Sep   Oct  count uid_final  \
# 0  2001  FS2001_MTHS.tif     23     9   392    8  4301  6935  11668         1
#
#          Laiskey  band
# 0  000     03736     1
# ----------------------------------------------------------------------------
# FS2001_MTHS.tif 2001 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  March  May    Oct  Nov  Dec  count
# 0  2002  FS2002_MTHS.tif    140  403  11387  621  535  13086
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  March  May    Oct  Nov  Dec  count uid_final  \
# 0  2002  FS2002_MTHS.tif    140  403  11387  621  535  13086         1
#
#          Laiskey  band
# 0  000     03736     1
# ----------------------------------------------------------------------------
# FS2002_MTHS.tif 2002 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  count
# 0  2003  FS2003_MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  count uid_final        Laiskey  band
# 0  2003  FS2003_MTHS.tif      0         1  000     03736     1
# ----------------------------------------------------------------------------
# FS2003_MTHS.tif 2003 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  April  May  July  Aug   Oct   Nov  Dec  count
# 0  2004  FS2004_MTHS.tif    420  476     3  148  6195  1814   27   9083
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  April  May  July  Aug   Oct   Nov  Dec  count  \
# 0  2004  FS2004_MTHS.tif    420  476     3  148  6195  1814   27   9083
#
#   uid_final        Laiskey  band
# 0         1  000     03736     1
# ----------------------------------------------------------------------------
# FS2004_MTHS.tif 2004 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  April  count
# 0  2005  FS2005_MTHS.tif      1      1
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  April  count uid_final        Laiskey  band
# 0  2005  FS2005_MTHS.tif      1      1         1  000     03736     1
# ----------------------------------------------------------------------------
# FS2005_MTHS.tif 2005 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  May  Sep   Nov  255.0  count
# 0  2006  FS2006_MTH.tif  344   33  9511  27756  37644
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  May  Sep   Nov  255.0  count uid_final  \
# 0  2006  FS2006_MTH.tif  344   33  9511  27756  37644         1
#
#          Laiskey  band
# 0  000     03736     1
# ----------------------------------------------------------------------------
# FS2006_MTH.tif 2006 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  May  Oct  Dec  255.0  count
# 0  2007  FS2007_MTH.tif    1  846  847  35891  37585
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  May  Oct  Dec  255.0  count uid_final        Laiskey  \
# 0  2007  FS2007_MTH.tif    1  846  847  35891  37585         1  000     03736
#
#    band
# 0     1
# ----------------------------------------------------------------------------
# FS2007_MTH.tif 2007 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  April  May  July  Dec  count
# 0  2008  FS2008_MTH.tif   1219    5     1   32   1257
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  April  May  July  Dec  count uid_final  \
# 0  2008  FS2008_MTH.tif   1219    5     1   32   1257         1
#
#          Laiskey  band
# 0  000     03736     1
# ----------------------------------------------------------------------------
# FS2008_MTH.tif 2008 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  March   May  July  Oct   Nov  Dec  255.0  count
# 0  2009  FS2009_MTH.tif      2  1891    12   15  8958   79  26699  37656
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  March   May  July  Oct   Nov  Dec  255.0  count  \
# 0  2009  FS2009_MTH.tif      2  1891    12   15  8958   79  26699  37656
#
#   uid_final        Laiskey  band
# 0         1  000     03736     1
# ----------------------------------------------------------------------------
# FS2009_MTH.tif 2009 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  April  June  Sep  255.0  count
# 0  2010  FS2010_MTH.tif    170    11  195  37290  37666
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  April  June  Sep  255.0  count uid_final  \
# 0  2010  FS2010_MTH.tif    170    11  195  37290  37666         1
#
#          Laiskey  band
# 0  000     03736     1
# ----------------------------------------------------------------------------
# FS2010_MTH.tif 2010 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\camfield_GDA94.shp
# ...
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  Sep  count
# 0  2001  FS2001_MTHS.tif  366    366
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  Sep  count uid_final        Laiskey  band
# 0  2001  FS2001_MTHS.tif  366    366         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2001_MTHS.tif 2001 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  July   Nov   Dec  count
# 0  2002  FS2002_MTHS.tif    35  2330  1975   4340
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  July   Nov   Dec  count uid_final        Laiskey  \
# 0  2002  FS2002_MTHS.tif    35  2330  1975   4340         1  000     00641
#
#    band
# 0     1
# ----------------------------------------------------------------------------
# FS2002_MTHS.tif 2002 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  count
# 0  2003  FS2003_MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  count uid_final        Laiskey  band
# 0  2003  FS2003_MTHS.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2003_MTHS.tif 2003 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  count
# 0  2004  FS2004_MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  count uid_final        Laiskey  band
# 0  2004  FS2004_MTHS.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2004_MTHS.tif 2004 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  count
# 0  2005  FS2005_MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  count uid_final        Laiskey  band
# 0  2005  FS2005_MTHS.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2005_MTHS.tif 2005 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  255.0  count
# 0  2006  FS2006_MTH.tif  32650  32650
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  255.0  count uid_final        Laiskey  band
# 0  2006  FS2006_MTH.tif  32650  32650         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2006_MTH.tif 2006 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  255.0  count
# 0  2007  FS2007_MTH.tif  32414  32414
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  255.0  count uid_final        Laiskey  band
# 0  2007  FS2007_MTH.tif  32414  32414         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2007_MTH.tif 2007 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2008  FS2008_MTH.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2008  FS2008_MTH.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2008_MTH.tif 2008 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  255.0  count
# 0  2009  FS2009_MTH.tif  32392  32392
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  255.0  count uid_final        Laiskey  band
# 0  2009  FS2009_MTH.tif  32392  32392         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2009_MTH.tif 2009 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  255.0  count
# 0  2010  FS2010_MTH.tif  32424  32424
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  255.0  count uid_final        Laiskey  band
# 0  2010  FS2010_MTH.tif  32424  32424         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2010_MTH.tif 2010 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  July  Aug   Sep   Oct  count
# 0  2011  FS2011_MTH.tif   277   14  9743  3351  13385
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  July  Aug   Sep   Oct  count uid_final  \
# 0  2011  FS2011_MTH.tif   277   14  9743  3351  13385         1
#
#          Laiskey  band
# 0  000     00641     1
# ----------------------------------------------------------------------------
# FS2011_MTH.tif 2011 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  July   Nov  255.0  count
# 0  2012  FS2012_MTH.tif     8  3416  28990  32414
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  July   Nov  255.0  count uid_final        Laiskey  \
# 0  2012  FS2012_MTH.tif     8  3416  28990  32414         1  000     00641
#
#    band
# 0     1
# ----------------------------------------------------------------------------
# FS2012_MTH.tif 2012 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2013  FS2013_MTH.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2013  FS2013_MTH.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2013_MTH.tif 2013 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2014  FS2014_MTH.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2014  FS2014_MTH.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2014_MTH.tif 2014 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2015  FS2015_MTH.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2015  FS2015_MTH.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2015_MTH.tif 2015 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2016  FS2016_MTH.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2016  FS2016_MTH.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2016_MTH.tif 2016 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year            image  April  count
# 0  2017  FS2017_MTHS.tif    134    134
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year            image  April  count uid_final        Laiskey  band
# 0  2017  FS2017_MTHS.tif    134    134         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2017_MTHS.tif 2017 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year        image  count
# 0  2018  fs2018M.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year        image  count uid_final        Laiskey  band
# 0  2018  fs2018M.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# fs2018M.tif 2018 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year           image  count
# 0  2019  FS2019MTHS.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year           image  count uid_final        Laiskey  band
# 0  2019  FS2019MTHS.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# FS2019MTHS.tif 2019 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:
# TOTAL_UID_LIST as it happens:  []
# UID_LIST:  []
# ============================================================================
#    year       image  count
# 0  2020  fs2020.tif      0
# ----------------------------------------------------------------------------
# TOTAL_UID_LIST:  ['1']
# ============================================================================
# nnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnnn
#    year       image  count uid_final        Laiskey  band
# 0  2020  fs2020.tif      0         1  000     00641     1
# ----------------------------------------------------------------------------
# fs2020.tif 2020 zone stats are complete
# Property name:  D:\Rob\fire\test_properties\work_comp\yambah_GDA94.shp
# Clean_Prop_Name:

# %% [markdown]
# ## First attempt

# %% [markdown]
# Issues:
#     can not include uid

# %%
First attempt
issues can not include uid

for shape in shapefile_list:
    shape.strip()
    
    # check if the "temp_individual_bands" file already exists and delete it if it does.
    tempDir = 'temp_individual_bands'       
    try:
        shutil.rmtree(tempDir)

    except:
        print("The following directory was deleted: ", tempDir)

    # create temporary folders
    tempDir = 'temp_individual_bands'
    os.makedirs(tempDir)


    def listdir(dirname,endfilename,scratchDir):
        """
        this function will return a list of files in a directory for the given file extention "endfilename". 
        """
        list_img = []

        for root, dirs, files in os.walk(dirname):
            for file in files:
                if file.endswith(endfilename):
                    img = (os.path.join(root, file))
                    list_img.append(img)
                    #print (img)
                    shutil.copy(os.path.abspath(img), scratchDir)
        print("Script has finished")
        return list_img

    dirname = r'U:\Working\Rangelands\Spatial Data\NAFI Firescars'
    endfilename = 'MTH.tif'
    scratchDir = r'C:\Users\rmcgr\Desktop\firemaps\scratch'

    listdir(dirname,endfilename,scratchDir)



    imlist = r"Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters\fire_list.csv"
    shape = shape
    image_name =[]
    image_date =[]
    site_li =[]
    zoneclass =[]
    zoneresults =[]
    uid_list = []
    property_list = []



    #def mainRoutine():

    # read in the command arguments
    """cmdargs = getCmdargs()
    imlist = cmdargs.imlist
    nodata= int(cmdargs.nodata)
    shape = cmdargs.shape 
    uid = cmdargs.uid
    export_csv = cmdargs.csv""" 

    # check if the "temp_individual_bands" file already exists and delete it if it does.
    """tempDir = 'temp_individual_bands'       
    try:
        shutil.rmtree(tempDir)

    except:
        print("The following directory was deleted: ", tempDir)"""

    # create temporary folders
    #tempDir = 'temp_individual_bands'
    #os.makedirs(tempDir)

    with open(imlist, "r") as imagerylist:

        #Extract each image path from the image list
        for image in imagerylist:
            print(image)

            # cleans the file pathway (Windows)
            imageS = image.rstrip()
            print("imageS: ", imageS)
            im_name = imageS[60:]
            print("Im_Name: ", im_name)

            # loops through each image
            with rasterio.open(imageS, nodata= 255) as srci:
                imageResults = 'image_' + im_name + '.csv'
                # runs the zonal stats function and outputs a csv in a band specific folder
                #finalresults = applyZonalstats(imageS, nodata, band, shape, uid)

                """--------------------------------------------------------------------------------------------------------------"""

                #def applyZonalstats(imageS, nodata, band, shape, uid):

                '''image_name =[]
                image_date =[]
                site_li =[]
                zoneclass =[]
                zoneresults =[]'''

                with rasterio.open(imageS, nodata=255) as srci:
                    affine = srci.transform #srci.transform is the new srci.affine
                    array = srci.read(1)
                    print(array)

                    with fiona.open(shape) as src:
                        # using "all_touched=True" will increase the number of pixels used to produce the stats "False" reduces the number

                        cmap = {1: 'Jan', 2: 'Feb', 3: 'March', 4: 'April', 5: 'May', 6: 'June', 7: 'July', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
                        zs = zonal_stats(src, array, affine=affine, stats=['count'],categorical=True, 
                                         category_map=cmap, nodata = 255, all_touched=False)

                        print("ZS: ", zs)
                        print("Array: ", array)

                        # extract image name and append to list
                        imgName = str(srci)[86:-11]
                        print("imgName: ", imgName)
                        image_name.append(imgName)
                        # extract image date and append to list
                        imgDate = str(imgName)[2:6]
                        print("imgDate: ", imgDate)
                        image_date.append(imgDate)

                        df  = pd.DataFrame.from_records(zs)
                        df.insert(0, 'image', imgName)
                        df.insert(0, 'year', imgDate)
                        
                        uid_list = []
                        property_list = []

                        for i in src:

                            # extract shapefile records
                            table_attributes = i['properties'] 
                            
                            uid_ = table_attributes["uid"]
                            uid_string = str(uid_)
                            uid_list.append(uid_string)
                            #df.insert(0, 'site', prop)

                            prop = table_attributes["PROP_NAME"]
                            property_list.append(prop)
                            #df.insert(0, 'property', prop)

                        #df.insert(0, 'site', property_list)
                        df.insert(0, 'property', prop)
                        #df.insert(0, 'site', uid_)
                        #df = df.append(pd.DataFrame(property_list, columns=['property']))
                        print("UID_LIST: ", uid_list)
                        #df['site'].append(uid_string)
                        df.to_csv(tempDir + '//' + imageResults, index=False) 

                        srci.close()

                        # print out the file name of the processed image
                        print (imgName + ' ' + imgDate +  ' ' + 'zone stats are complete')

                        #return(finalresults)

                        """--------------------------------------------------------------------------------------------------------"""

                        #RETURN TO MAIN FUNCTION

                        #header = ['number', 'site', 'min', 'max', 'mean', 'count']#, 'std', 'median'

                        """df  = pd.DataFrame.from_records(finalresults)
                        #df['band']= band
                        df['image']= imgName
                        df['date']= imgDate
                        print("DF: ", df)
                        df.to_csv(tempDir + '//' + imageResults, index=False) """
                        # join the elements in each of the lists row by row 
                        #finalresults =  [uid_list + property_list + imU for siteid, zoneR, imU in zip(siteID, zonestats,image_Name)] 

    property_name = shape.rstrip()
    print("Property name: ", property_name)
    clean_prop_name = property_name[98:-4]
    print("Clean_Prop_Name: ", clean_prop_name)


    # for loops through the band folders and concatenates zonal stat outputs into a complete band specific csv   
    band_files = glob.glob(os.path.join(tempDir, "*.csv")) # advisable to use os.path.join as this makes concatenation OS independent
    df_from_each_band_file = (pd.read_csv(f) for f in band_files)
    concat_band_df   = pd.concat(df_from_each_band_file,ignore_index=False, axis=0, sort=False)
    #concat_band_df = concat_band_df.insert(0, 'property', prop)
    # export the band specific results to a csv file (i.e. three outputs)
    concat_band_df.to_csv(r"\\pgb-bas01\DENR_Satellite_Imagery$\Scratch\Zonal_Stats_Pipeline\Firescars\outputs" + '\\' + clean_prop_name + "_fire_scar.csv",index=False)

# %% [markdown]
# # NAFI 2020 raster clasification

# %% [markdown]
# https://www.neonscience.org/resources/data-tutorials

# %% [markdown]
# https://www.neonscience.org/classify-raster-thresholds-py

# %%
import numpy as np
import gdal
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
chm_filename = r'Z:\Scratch\Zonal_Stats_Pipeline\Firescars\NAFI_fire_rasters\fs2020.tif'
chm_dataset = gdal.Open(chm_filename)

# %%
#Display the dataset dimensions, number of bands, driver, and geotransform 
cols = chm_dataset.RasterXSize; print('# of columns:',cols)
rows = chm_dataset.RasterYSize; print('# of rows:',rows)
print('# of bands:',chm_dataset.RasterCount)
print('driver:',chm_dataset.GetDriver().LongName)

# %%
print('projection:',chm_dataset.GetProjection())

# %%
print('geotransform:',chm_dataset.GetGeoTransform())

# %%
chm_mapinfo = chm_dataset.GetGeoTransform()
xMin = chm_mapinfo[0]
yMax = chm_mapinfo[3]

xMax = xMin + chm_dataset.RasterXSize/chm_mapinfo[1] #divide by pixel width 
yMin = yMax + chm_dataset.RasterYSize/chm_mapinfo[5] #divide by pixel height (note sign +/-)
chm_ext = (xMin,xMax,yMin,yMax)
print('chm raster extent:',chm_ext)

# %%
chm_raster = chm_dataset.GetRasterBand(1)
noDataVal = chm_raster.GetNoDataValue(); print('no data value:',noDataVal)
scaleFactor = chm_raster.GetScale(); print('scale factor:',scaleFactor)
chm_stats = chm_raster.GetStatistics(True,True)
print('SERC CHM Statistics: Minimum=%.2f, Maximum=%.2f, Mean=%.3f, StDev=%.3f' % 
      (chm_stats[0], chm_stats[1], chm_stats[2], chm_stats[3]))

# %%
chm_array = chm_dataset.GetRasterBand(1).ReadAsArray(0,0,cols,rows).astype(np.float)
chm_array[chm_array==int(noDataVal)]=np.nan #Assign CHM No Data Values to NaN
chm_array=chm_array/scaleFactor
print('SERC CHM Array:\n',chm_array) #display array values

# %%
# Display statistics (min, max, mean); numpy.nanmin calculates the minimum without the NaN values.
print('Array Statistics:')
print('min:',round(np.nanmin(chm_array),2))
print('max:',round(np.nanmax(chm_array),2))
print('mean:',round(np.nanmean(chm_array),2))

# Calculate the % of pixels that are NaN and non-zero:
pct_nan = np.count_nonzero(np.isnan(chm_array))/(rows*cols)
print('% NaN:',round(pct_nan*100,2))
print('% non-zero:',round(100*np.count_nonzero(chm_array)/(rows*cols),2))

# %%
# Define the plot_band_array function from Day 1
def plot_band_array(band_array,refl_extent,colorlimit,ax=plt.gca(),title='',cbar ='on',cmap_title='',colormap='BuGn'):
    plot = plt.imshow(band_array,extent=refl_extent,clim=colorlimit); 
    if cbar == 'on':
        cbar = plt.colorbar(plot,aspect=40); plt.set_cmap(colormap); 
        cbar.set_label(cmap_title,rotation=90,labelpad=20);
    plt.title(title); ax = plt.gca(); 
    ax.ticklabel_format(useOffset=False, style='plain'); #do not use scientific notation #
    rotatexlabels = plt.setp(ax.get_xticklabels(),rotation=90); #rotate x tick labels 90 degrees

# %%
plot_band_array(chm_array,chm_ext,(1,100),title='NAFI Fire map',cmap_title='Raster values')

# %%
import copy
chm_nonan_array = copy.copy(chm_array)
chm_nonan_array = chm_nonan_array[~np.isnan(chm_array)]
plt.hist(chm_nonan_array,weights=np.zeros_like(chm_nonan_array)+1./
         (chm_array.shape[0]*chm_array.shape[1]),bins=10);
plt.title('Distribution of NAFI pixcel values')
plt.xlabel('Pixcel values'); plt.ylabel('Relative Frequency')

# %%
chm_nonzero_array = copy.copy(chm_array)
chm_nonzero_array[chm_array==0]=np.nan
chm_nonzero_nonan_array = chm_nonzero_array[~np.isnan(chm_nonzero_array)]
# Use weighting to plot relative frequency
plt.hist(chm_nonzero_nonan_array,weights=np.zeros_like(chm_nonzero_nonan_array)+1./
         (chm_array.shape[0]*chm_array.shape[1]),bins=50);

# plt.hist(chm_nonzero_nonan_array.flatten(),50) 
plt.title('Distribution of SERC Non-Zero Canopy Height')
plt.xlabel('Tree Height (m)'); plt.ylabel('Relative Frequency')
# plt.xlim(0,25); plt.ylim(0,4000000)

print('min:',np.amin(chm_nonzero_nonan_array),'m')
print('max:',round(np.amax(chm_nonzero_nonan_array),2),'m')
print('mean:',round(np.mean(chm_nonzero_nonan_array),2),'m')

# %%
plot_band_array(chm_array,chm_ext,(0,100),title='SERC Canopy Height',cmap_title='Canopy Height, m',colormap='BuGn')

# %%
# raster2array.py reads in the first band of geotif file and returns an array and associated 
# metadata dictionary

import numpy as np
import gdal
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from osgeo import gdal
import numpy as np
import copy



def raster2array(geotif_file):
    metadata = {}
    dataset = gdal.Open(geotif_file)
    metadata['array_rows'] = dataset.RasterYSize
    metadata['array_cols'] = dataset.RasterXSize
    metadata['bands'] = dataset.RasterCount
    metadata['driver'] = dataset.GetDriver().LongName
    metadata['projection'] = dataset.GetProjection()
    metadata['geotransform'] = dataset.GetGeoTransform()

    mapinfo = dataset.GetGeoTransform()
    metadata['pixelWidth'] = mapinfo[1]
    metadata['pixelHeight'] = mapinfo[5]

    metadata['ext_dict'] = {}
    metadata['ext_dict']['xMin'] = mapinfo[0]
    metadata['ext_dict']['xMax'] = mapinfo[0] + dataset.RasterXSize/mapinfo[1]
    metadata['ext_dict']['yMin'] = mapinfo[3] + dataset.RasterYSize/mapinfo[5]
    metadata['ext_dict']['yMax'] = mapinfo[3]

    metadata['extent'] = (metadata['ext_dict']['xMin'],metadata['ext_dict']['xMax'],
                          metadata['ext_dict']['yMin'],metadata['ext_dict']['yMax'])

    if metadata['bands'] == 1:
        raster = dataset.GetRasterBand(1)
        metadata['noDataValue'] = raster.GetNoDataValue()
        metadata['scaleFactor'] = raster.GetScale()

        # band statistics
        metadata['bandstats'] = {} #make a nested dictionary to store band stats in same 
        stats = raster.GetStatistics(True,True)
        metadata['bandstats']['min'] = round(stats[0],2)
        metadata['bandstats']['max'] = round(stats[1],2)
        metadata['bandstats']['mean'] = round(stats[2],2)
        metadata['bandstats']['stdev'] = round(stats[3],2)

        array = dataset.GetRasterBand(1).ReadAsArray(0,0,metadata['array_cols'],metadata['array_rows']).astype(np.float)
        array[array==int(metadata['noDataValue'])]=np.nan
        array = array/metadata['scaleFactor']
        return array, metadata

    elif metadata['bands'] > 1:
        print('More than one band ... need to modify function for case of multiple bands')

# %%
NAFI_array, NAFI_metadata = raster2array(r'T:\rob\edit_test\fs2020.tif')

print('NAFI_Array:\n',NAFI_array)

#print metadata in alphabetical order
for item in sorted(NAFI_metadata):
    print(item + ':', NAFI_metadata[item])

# %%
NAFI_reclass = copy.copy(NAFI_array)
NAFI_reclass[np.where(NAFI_array== 0)] = 255 # Class No data
NAFI_reclass[np.where((NAFI_array>1) & (NAFI_array<=8))] = 2 #  Class Jan
NAFI_reclass[np.where((NAFI_array>8) & (NAFI_array<=16))] = 3 #  Class Feb
NAFI_reclass[np.where((NAFI_array>17) & (NAFI_array<=26))] = 4 # March
NAFI_reclass[np.where((NAFI_array>27) & (NAFI_array<=36))] = 5 #  April
NAFI_reclass[np.where((NAFI_array>37) & (NAFI_array<=55))] = 6 #  Class May
NAFI_reclass[np.where((NAFI_array>56) & (NAFI_array<=84))] = 7 #  Class June
NAFI_reclass[np.where((NAFI_array>85) & (NAFI_array<=115))] = 8 #  Class July
NAFI_reclass[np.where((NAFI_array>116) & (NAFI_array<=145))] = 9 #  Class August
NAFI_reclass[np.where((NAFI_array>146) & (NAFI_array<=175))] = 10 #  Class September
NAFI_reclass[np.where(NAFI_array>176)] = 255 #  Class No data
"""NAFI_reclass[np.where((NAFI_array>206) & (NAFI_array<=231))] = 11 #  Class November
NAFI_reclass[np.where((NAFI_array>232) & (NAFI_array<=254))] = 12 #  Class December"""
#NAFI_reclass[np.where(NAFI_array== 0)] = 10 # Class No data

print('Min:',np.nanmin(NAFI_reclass))
print('Max:',np.nanmax(NAFI_reclass))
print('Mean:',round(np.nanmean(NAFI_reclass),2))


import matplotlib.colors as colors
plt.figure(); #ax = plt.subplots()
cmapNAFI = colors.ListedColormap([
    'black',
    'peru',
    'peachpuff',
    'yellowgreen',
    'khaki',
    'red',
    'orange',
    'darkred',
    'red',
    'springgreen',
    'white'
])

extents=[6000,1200,0,500]

plt.imshow(NAFI_reclass,  cmap=cmapNAFI) #extent=extents,
plt.title('NAFI month breakdown')
ax=plt.gca(); ax.ticklabel_format(useOffset=False, style='plain') #do not use scientific notation 
rotatexlabels = plt.setp(ax.get_xticklabels(),rotation=90) #rotate x tick labels 90 degrees
# forceAspect(ax,aspect=1) # ax.set_aspect('auto')

# Create custom legend to label the four canopy height classes:
import matplotlib.patches as mpatches
class1_box = mpatches.Patch(color='peru', label='Jan')
class2_box = mpatches.Patch(color='peachpuff', label='Feb')
class3_box = mpatches.Patch(color='yellowgreen', label='Mar')
class4_box = mpatches.Patch(color='khaki', label='April')
class5_box = mpatches.Patch(color='red', label='May')
class6_box = mpatches.Patch(color='orange', label='June')
class7_box = mpatches.Patch(color='darkred', label='July')
class8_box = mpatches.Patch(color='red', label='Aug')
class9_box = mpatches.Patch(color='springgreen', label='Sep')
class10_box = mpatches.Patch(color='blue', label='Oct')
#class11_box = mpatches.Patch(color='tan', label='Nov')
#class12_box = mpatches.Patch(color='maroon', label='Dec')
#class13_box = mpatches.Patch(color='red', label='No data')
#class14_box = mpatches.Patch(color='black', label='255')



ax.legend(handles=[class1_box,class2_box,class3_box,class4_box, class5_box, class6_box,
                  class7_box,class8_box,class9_box],
          handlelength=0.7,bbox_to_anchor=(1.05, 0.4),loc='lower left',borderaxespad=0.)

# %%
# %load ../hyperspectral_hdf5/array2raster.py
"""
Array to Raster Function from https://pcjericks.github.io/py-gdalogr-cookbook/raster_layers.html)
"""
import gdal, osr #ogr, os, osr
import numpy as np

def array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array,epsg):

    cols = array.shape[1]
    rows = array.shape[0]
    originX = rasterOrigin[0]
    originY = rasterOrigin[1]

    driver = gdal.GetDriverByName('GTiff')
    outRaster = driver.Create(newRasterfn, cols, rows, 1, gdal.GDT_Byte)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    outband = outRaster.GetRasterBand(1)
    outband.WriteArray(array)
    outRasterSRS = osr.SpatialReference()
    outRasterSRS.ImportFromEPSG(epsg)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()

# %%
# array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array)
epsg = 4283   # GDA94 
rasterOrigin = (NAFI_metadata['ext_dict']['xMin'],NAFI_metadata['ext_dict']['yMax'])
print('raster origin:',rasterOrigin)
array2raster('NAFI_Classified.tif',rasterOrigin,1,-1,chm_reclass,epsg)
